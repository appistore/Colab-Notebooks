# %% [markdown]
# #Tri par selection

# %% [markdown]
# #Tri par Selection en utilisation une procedure

# %%
def selection(a): # Function to implement selection sort
    for i in range(len(a)): # Traverse through all array elements
        small = i # minimum element in unsorted array
        for j in range(i+1, len(a)):
            if a[small] > a[j]:
                small = j
    # Swap the found minimum element with
    # the first element
        a[i], a[small] = a[small], a[i]

def printArr(a): # function to print the array

    for i in range(len(a)):
        print (a[i], end = " ")

# %%
import numpy as np
a = [np.random.randint(20) for k in range(10)]

print("Before sorting array elements are : " )
printArr(a)
selection(a)
print("\nAfter sorting array elements are : ")
selection(a)
printArr(a)
# Out:
# Before sorting array elements are :
# 1 15 14 4 17 10 13 1 1 13
# After sorting array elements are :
# 1 1 1 4 10 13 13 14 15 17
